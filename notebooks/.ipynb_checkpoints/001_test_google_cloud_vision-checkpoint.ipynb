# %%
import argparse
import io


from google.cloud import vision
from PIL import Image

# %%
filename = '/Users/olgabot/Downloads/Hair products/image.png'
Image.open(filename)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=522x516 at 0x11051E898>

# %%
! export "GOOGLE_APPLICATION_CREDENTIALS=$HOME/.gcloud/dupe-app-4361420ec4e6.json"

# %%
import sys

# %%
import os

# %%
print(os.environ)
# Out:
# environ({'TMPDIR': '/var/folders/70/9pmmxs613fg12b1kl7gkgfjm0000gn/T/', 'XPC_FLAGS': '0x0', 'Apple_PubSub_Socket_Render': '/private/tmp/com.apple.launchd.tz1kMptjXm/Render', 'LANG': 'en_US.UTF-8', 'DBUS_LAUNCHD_SESSION_BUS_SOCKET': '/private/tmp/com.apple.launchd.sStqYqN6Qe/unix_domain_listener', 'DISPLAY': '/private/tmp/com.apple.launchd.1DQopJdjYK/org.macosforge.xquartz:0', 'SSH_AUTH_SOCK': '/var/folders/70/9pmmxs613fg12b1kl7gkgfjm0000gn/T//ssh-K4NySvqjOXXz/agent.1346', 'SECURITYSESSIONID': '186a7', 'TERM': 'xterm-color', 'TERM_PROGRAM': 'Apple_Terminal', 'XPC_SERVICE_NAME': '0', 'TERM_PROGRAM_VERSION': '388.1.2', 'TERM_SESSION_ID': 'BC8EF87E-BB95-4DCC-A04C-CD711EC59485', '__CF_USER_TEXT_ENCODING': '0x1F5:0x0:0x0', 'SHELL': '/bin/zsh', 'HOME': '/Users/olgabot', 'LOGNAME': 'olgabot', 'USER': 'olgabot', 'PATH': '/Users/olgabot/anaconda3/bin:/Users/olgabot/anaconda3/bin:/Users/olgabot/bin:/usr/local/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/opt/X11/bin:/Library/TeX/texbin:/Users/olgabot/go/bin', 'SHLVL': '1', 'PWD': '/Users/olgabot/code', 'OLDPWD': '/Users/olgabot', 'ZSH': '/Users/olgabot/.oh-my-zsh', 'PAGER': 'cat', 'LESS': '-R', 'LSCOLORS': 'Gxfxcxdxbxegedabagacad', 'LC_CTYPE': 'en_US.UTF-8', 'EDITOR': 'emacs', 'SSH_KEY_PATH': '~/.ssh/rsa_id', 'CONDA_SHLVL': '1', 'CONDA_DEFAULT_ENV': 'base', 'CONDA_PREFIX': '/Users/olgabot/anaconda3', 'CONDA_PROMPT_MODIFIER': '(base) ', 'CONDA_PYTHON_EXE': '/Users/olgabot/anaconda3/bin/python', 'SSH_AGENT_PID': '1350', 'AWS_SDK_LOAD_CONFIG': '1', '_': '/Users/olgabot/anaconda3/bin/jupyter', 'JPY_PARENT_PID': '53320', 'CLICOLOR': '1', 'GIT_PAGER': 'cat', 'MPLBACKEND': 'module://ipykernel.pylab.backend_inline'})

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = "/Users/olgabot/.gcloud/dupe-app-4361420ec4e6.json"

# %%
def detect_text(path):
    """Detects text in the file."""
    client = vision.ImageAnnotatorClient()

    with io.open(path, 'rb') as image_file:
        content = image_file.read()

    image = vision.types.Image(content=content)

    response = client.text_detection(image=image)
    texts = response.text_annotations
    print('Texts:')

    for text in texts:
        print('\n"{}"'.format(text.description))

        vertices = (['({},{})'.format(vertex.x, vertex.y)
                    for vertex in text.bounding_poly.vertices])

        print('bounds: {}'.format(','.join(vertices)))

detect_text(filename)
# Out:
# ---------------------------------------------------------------------------
# _Rendezvous                               Traceback (most recent call last)
# ~/anaconda3/envs/dupe-env/lib/python3.6/site-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      53         try:
# ---> 54             return callable_(*args, **kwargs)
#      55         except grpc.RpcError as exc:
#
# ~/anaconda3/envs/dupe-env/lib/python3.6/site-packages/grpc/_channel.py in __call__(self, request, timeout, metadata, credentials)
#     499         state, call, = self._blocking(request, timeout, metadata, credentials)
# --> 500         return _end_unary_response_blocking(state, call, False, None)
#     501
#
# ~/anaconda3/envs/dupe-env/lib/python3.6/site-packages/grpc/_channel.py in _end_unary_response_blocking(state, call, with_call, deadline)
#     433     else:
# --> 434         raise _Rendezvous(state, None, None, deadline)
#     435
#
# _Rendezvous: <_Rendezvous of RPC that terminated with (StatusCode.PERMISSION_DENIED, This API method requires billing to be enabled. Please enable billing on project #350193883757 by visiting https://console.developers.google.com/billing/enable?project=350193883757 then retry. If you enabled billing for this project recently, wait a few minutes for the action to propagate to our systems and retry.)>
#
# The above exception was the direct cause of the following exception:
#
# PermissionDenied                          Traceback (most recent call last)
# <ipython-input-23-dec6b9765adb> in <module>()
#      20         print('bounds: {}'.format(','.join(vertices)))
#      21
# ---> 22 detect_text(filename)
#
# <ipython-input-23-dec6b9765adb> in detect_text(path)
#       8     image = vision.types.Image(content=content)
#       9
# ---> 10     response = client.text_detection(image=image)
#      11     texts = response.text_annotations
#      12     print('Texts:')
#
# ~/anaconda3/envs/dupe-env/lib/python3.6/site-packages/google/cloud/vision_helpers/decorators.py in inner(self, image, max_results, retry, timeout, **kwargs)
#     115             **kwargs
#     116         )
# --> 117         response = self.annotate_image(request, retry=retry, timeout=timeout)
#     118         return response
#     119
#
# ~/anaconda3/envs/dupe-env/lib/python3.6/site-packages/google/cloud/vision_helpers/__init__.py in annotate_image(self, request, retry, timeout)
#      65         # of them.
#      66         protobuf.setdefault(request, 'features', self._get_all_features())
# ---> 67         r = self.batch_annotate_images([request], retry=retry, timeout=timeout)
#      68         return r.responses[0]
#      69
#
# ~/anaconda3/envs/dupe-env/lib/python3.6/site-packages/google/cloud/vision_v1/gapic/image_annotator_client.py in batch_annotate_images(self, requests, retry, timeout, metadata)
#     163             requests=requests, )
#     164         return self._batch_annotate_images(
# --> 165             request, retry=retry, timeout=timeout, metadata=metadata)
#
# ~/anaconda3/envs/dupe-env/lib/python3.6/site-packages/google/api_core/gapic_v1/method.py in __call__(self, *args, **kwargs)
#     137             kwargs['metadata'] = metadata
#     138
# --> 139         return wrapped_func(*args, **kwargs)
#     140
#     141
#
# ~/anaconda3/envs/dupe-env/lib/python3.6/site-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      54             return callable_(*args, **kwargs)
#      55         except grpc.RpcError as exc:
# ---> 56             six.raise_from(exceptions.from_grpc_error(exc), exc)
#      57
#      58     return error_remapped_callable
#
# ~/anaconda3/envs/dupe-env/lib/python3.6/site-packages/six.py in raise_from(value, from_value)
#
# PermissionDenied: 403 This API method requires billing to be enabled. Please enable billing on project #350193883757 by visiting https://console.developers.google.com/billing/enable?project=350193883757 then retry. If you enabled billing for this project recently, wait a few minutes for the action to propagate to our systems and retry.

# %% [markdown]
# Make application credentials

# %%
def implicit():
    from google.cloud import storage

    # If you don't specify credentials when constructing the client, the
    # client library will look for credentials in the environment.
    storage_client = storage.Client()

    # Make an authenticated API request
    buckets = list(storage_client.list_buckets())
    print(buckets)

# %%
implicit()
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# <ipython-input-8-31fbdeff8103> in <module>()
# ----> 1 implicit()
#
# <ipython-input-7-ec4a97262892> in implicit()
#       4     # If you don't specify credentials when constructing the client, the
#       5     # client library will look for credentials in the environment.
# ----> 6     storage_client = storage.Client()
#       7
#       8     # Make an authenticated API request
#
# ~/anaconda3/envs/dupe-env/lib/python3.6/site-packages/google/cloud/storage/client.py in __init__(self, project, credentials, _http)
#      57         self._base_connection = None
#      58         super(Client, self).__init__(project=project, credentials=credentials,
# ---> 59                                      _http=_http)
#      60         self._connection = Connection(self)
#      61         self._batch_stack = _LocalStack()
#
# ~/anaconda3/envs/dupe-env/lib/python3.6/site-packages/google/cloud/client.py in __init__(self, project, credentials, _http)
#     213
#     214     def __init__(self, project=None, credentials=None, _http=None):
# --> 215         _ClientProjectMixin.__init__(self, project=project)
#     216         Client.__init__(self, credentials=credentials, _http=_http)
#
# ~/anaconda3/envs/dupe-env/lib/python3.6/site-packages/google/cloud/client.py in __init__(self, project)
#     167
#     168     def __init__(self, project=None):
# --> 169         project = self._determine_default(project)
#     170         if project is None:
#     171             raise EnvironmentError('Project was not passed and could not be '
#
# ~/anaconda3/envs/dupe-env/lib/python3.6/site-packages/google/cloud/client.py in _determine_default(project)
#     180     def _determine_default(project):
#     181         """Helper:  use default project detection."""
# --> 182         return _determine_default_project(project)
#     183
#     184
#
# ~/anaconda3/envs/dupe-env/lib/python3.6/site-packages/google/cloud/_helpers.py in _determine_default_project(project)
#     177     """
#     178     if project is None:
# --> 179         _, project = google.auth.default()
#     180     return project
#     181
#
# ~/anaconda3/envs/dupe-env/lib/python3.6/site-packages/google/auth/_default.py in default(scopes, request)
#     281             return credentials, effective_project_id
#     282
# --> 283     raise exceptions.DefaultCredentialsError(_HELP_MESSAGE)
#
# DefaultCredentialsError: Could not automatically determine credentials. Please set GOOGLE_APPLICATION_CREDENTIALS or
# explicitly create credential and re-run the application. For more
# information, please see
# https://developers.google.com/accounts/docs/application-default-credentials.
